# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
consumer_insights = pd.read_csv('Sierra Nevadaconsumer_insights_survey.csv')

consumer_insights.head()
# Out:
#    Respondent_ID  Age  Gender Market          Favorite_Brand  \
# 0              1   29  Female     TX  Sierra Nevada Pale Ale
# 1              2   49  Female     NC  Sierra Nevada Hazy IPA
# 2              3   49  Female     CO          Competitor IPA
# 3              4   52    Male     CO          Competitor IPA
# 4              5   62  Female     CO        Competitor Lager
#
#   Purchase_Frequency Occasion  Sustainability_Importance
# 0             Weekly    Event                          1
# 1             Weekly  At-Home                          3
# 2             Weekly    Event                          3
# 3            Monthly      Bar                          4
# 4       Occasionally  At-Home                          3

# %%
consumer_insights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Respondent_ID              100 non-null    int64
#  1   Age                        100 non-null    int64
#  2   Gender                     100 non-null    object
#  3   Market                     100 non-null    object
#  4   Favorite_Brand             100 non-null    object
#  5   Purchase_Frequency         100 non-null    object
#  6   Occasion                   100 non-null    object
#  7   Sustainability_Importance  100 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 6.4+ KB

# %%
market_trends = pd.read_csv('Sierra Nevadamarket_trends.csv')

market_trends.head()
# Out:
#    Year  Quarter Market       Category  Growth_Rate (%)  SNBC_Share (%)  \
# 0  2024        3     TX  Non-Alcoholic             4.53            4.75
# 1  2024        2     PA          Lager            -3.80           10.27
# 2  2022        4     TX            IPA            -0.82           12.99
# 3  2023        2     CA  Non-Alcoholic            10.39            8.21
# 4  2022        2     PA  Non-Alcoholic            13.70            5.75
#
#    Competitor_Share (%)
# 0                  8.02
# 1                  2.83
# 2                  6.09
# 3                  9.08
# 4                 11.19

# %%
market_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  30 non-null     int64
#  1   Quarter               30 non-null     int64
#  2   Market                30 non-null     object
#  3   Category              30 non-null     object
#  4   Growth_Rate (%)       30 non-null     float64
#  5   SNBC_Share (%)        30 non-null     float64
#  6   Competitor_Share (%)  30 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.8+ KB

# %%
market_trends['Year'] = pd.to_datetime(market_trends['Year'], format='%Y', errors='coerce').dt.to_period('Y')

market_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  30 non-null     period[A-DEC]
#  1   Quarter               30 non-null     int64
#  2   Market                30 non-null     object
#  3   Category              30 non-null     object
#  4   Growth_Rate (%)       30 non-null     float64
#  5   SNBC_Share (%)        30 non-null     float64
#  6   Competitor_Share (%)  30 non-null     float64
# dtypes: float64(3), int64(1), object(2), period[A-DEC](1)
# memory usage: 1.8+ KB

# %%
planograms = pd.read_csv('Sierra Nevadaplanogram_data.csv')

planograms.head()
# Out:
#        Account Market  Shelf_Space_Linear_Feet                   Brand  \
# 0  Whole Foods     CA                      9.1   Sierra Nevada Torpedo
# 1       Costco     NC                     14.5          Competitor IPA
# 2  Whole Foods     PA                      5.1   Sierra Nevada Torpedo
# 3       Publix     CA                     10.1   Sierra Nevada Torpedo
# 4       Costco     NC                      4.7  Sierra Nevada Hazy IPA
#
#         Package  Facings  Sales_Per_Facing
# 0  Single Draft        7            336.05
# 1  12pk Bottles        5            428.74
# 2  12pk Bottles        9            213.92
# 3  Single Draft        7            342.36
# 4      6pk Cans        4            241.90

# %%
planograms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Account                  50 non-null     object
#  1   Market                   50 non-null     object
#  2   Shelf_Space_Linear_Feet  50 non-null     float64
#  3   Brand                    50 non-null     object
#  4   Package                  50 non-null     object
#  5   Facings                  50 non-null     int64
#  6   Sales_Per_Facing         50 non-null     float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.9+ KB

# %%
pricing_comparison = pd.read_csv('Sierra Nevadapricing_comparison.csv')

pricing_comparison.head()
# Out:
#   Market                   Brand       Package  Price_Per_Unit  \
# 0     TX   Sierra Nevada Torpedo  12pk Bottles            1.41
# 1     CO  Sierra Nevada Hazy IPA  Single Draft            1.67
# 2     TX          Competitor IPA      6pk Cans            2.60
# 3     CO        Competitor Lager  Single Draft            2.85
# 4     CO   Sierra Nevada Torpedo  12pk Bottles            1.41
#
#    Promotion_Discount (%) Competitor
# 0                      20          N
# 1                       0          N
# 2                      10          Y
# 3                       0          Y
# 4                       0          Y

# %%
pricing_comparison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Market                  50 non-null     object
#  1   Brand                   50 non-null     object
#  2   Package                 50 non-null     object
#  3   Price_Per_Unit          50 non-null     float64
#  4   Promotion_Discount (%)  50 non-null     int64
#  5   Competitor              50 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.5+ KB

# %%
promotion_results = pd.read_csv('Sierra Nevadapromotion_results.csv')

promotion_results.head()
# Out:
#   Market      Account                   Brand Promotion_Type  Start_Date  \
# 0     CO  Whole Foods          Competitor IPA        Display  2024-01-01
# 1     TX  Whole Foods          Competitor IPA      Price Cut  2024-01-08
# 2     NC       Publix  Sierra Nevada Hazy IPA           BOGO  2024-01-15
# 3     CO       Kroger        Competitor Lager        Display  2024-01-22
# 4     TX       Kroger  Sierra Nevada Pale Ale        Display  2024-01-29
#
#      End_Date  Incremental_Units   ROI
# 0  2024-01-08                623  1.99
# 1  2024-01-15                562  2.31
# 2  2024-01-22                807  0.68
# 3  2024-01-29                640  3.25
# 4  2024-02-05                835  4.19

# %%
promotion_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Market             40 non-null     object
#  1   Account            40 non-null     object
#  2   Brand              40 non-null     object
#  3   Promotion_Type     40 non-null     object
#  4   Start_Date         40 non-null     object
#  5   End_Date           40 non-null     object
#  6   Incremental_Units  40 non-null     int64
#  7   ROI                40 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.6+ KB

# %%
# updating start and end date to a datetime

promotion_results['Start_Date'] = pd.to_datetime(promotion_results['Start_Date'])
promotion_results['End_Date'] = pd.to_datetime(promotion_results['End_Date'])

# %%
promotion_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Market             40 non-null     object
#  1   Account            40 non-null     object
#  2   Brand              40 non-null     object
#  3   Promotion_Type     40 non-null     object
#  4   Start_Date         40 non-null     datetime64[ns]
#  5   End_Date           40 non-null     datetime64[ns]
#  6   Incremental_Units  40 non-null     int64
#  7   ROI                40 non-null     float64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 2.6+ KB

# %%
scan_data = pd.read_csv('Sierra Nevadasales_scan_data.csv')

scan_data.head()
# Out:
#          Date  Account Market                   Brand       Package  \
# 0  2024-09-01  Safeway     CO   Sierra Nevada Torpedo      6pk Cans
# 1  2024-05-05   Costco     CA          Competitor IPA  12pk Bottles
# 2  2024-12-08   Publix     CO  Sierra Nevada Hazy IPA      6pk Cans
# 3  2024-05-19   Costco     TX          Competitor IPA  Single Draft
# 4  2024-03-31   Kroger     TX  Sierra Nevada Hazy IPA  Single Draft
#
#    Units_Sold  Dollars_Sold Promoted
# 0         318       1009.53        N
# 1         327       3525.24        Y
# 2         425       3144.20        Y
# 3         193       2870.24        N
# 4         428       4216.18        N

# %%
scan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          200 non-null    object
#  1   Account       200 non-null    object
#  2   Market        200 non-null    object
#  3   Brand         200 non-null    object
#  4   Package       200 non-null    object
#  5   Units_Sold    200 non-null    int64
#  6   Dollars_Sold  200 non-null    float64
#  7   Promoted      200 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 12.6+ KB

# %%
# updating to datetime

scan_data['Date'] = pd.to_datetime(scan_data['Date'])

# %%
scan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          200 non-null    datetime64[ns]
#  1   Account       200 non-null    object
#  2   Market        200 non-null    object
#  3   Brand         200 non-null    object
#  4   Package       200 non-null    object
#  5   Units_Sold    200 non-null    int64
#  6   Dollars_Sold  200 non-null    float64
#  7   Promoted      200 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 12.6+ KB

# %% [markdown]
# # **Sales & Category Growth**
#
# * 1. Which Sierra Nevada products are growing fastest vs. declining in volume and dollars?
#
# * 2. How does SNBC’s sales growth compare to the category average in each market?
#
# * 3. What’s the sales mix between promoted and non-promoted volume?

# %% [markdown]
# ## 1. Which Sierra Nevada products are growing fastest vs. declining in volume and dollars?

# %%
# sorting scan data

scan_data = scan_data.sort_values(['Brand','Package', 'Date']).reset_index(drop=True)

# %%
scan_data.head()
# Out:
#         Date      Account Market           Brand       Package  Units_Sold  \
# 0 2024-02-11      Safeway     CA  Competitor IPA  12pk Bottles         250
# 1 2024-03-31      Safeway     CO  Competitor IPA  12pk Bottles         199
# 2 2024-04-28  Whole Foods     CO  Competitor IPA  12pk Bottles         407
# 3 2024-05-05       Costco     CA  Competitor IPA  12pk Bottles         327
# 4 2024-05-19       Costco     CO  Competitor IPA  12pk Bottles         302
#
#    Dollars_Sold Promoted
# 0       4636.22        Y
# 1       1181.20        N
# 2       2461.23        Y
# 3       3525.24        Y
# 4       2035.32        N

# %%
# creating a year/month column

scan_data['year_month'] = scan_data['Date'].dt.to_period('M').astype(str)

scan_data.head()
# Out:
#         Date      Account Market           Brand       Package  Units_Sold  \
# 0 2024-02-11      Safeway     CA  Competitor IPA  12pk Bottles         250
# 1 2024-03-31      Safeway     CO  Competitor IPA  12pk Bottles         199
# 2 2024-04-28  Whole Foods     CO  Competitor IPA  12pk Bottles         407
# 3 2024-05-05       Costco     CA  Competitor IPA  12pk Bottles         327
# 4 2024-05-19       Costco     CO  Competitor IPA  12pk Bottles         302
#
#    Dollars_Sold Promoted year_month
# 0       4636.22        Y    2024-02
# 1       1181.20        N    2024-03
# 2       2461.23        Y    2024-04
# 3       3525.24        Y    2024-05
# 4       2035.32        N    2024-05

# %%
# looking at monthly sales

monthly_sales = (scan_data
     .groupby(['year_month', 'Brand', 'Package'])
     .agg({
         'Units_Sold' : 'sum',
         'Dollars_Sold': 'sum'
     })
     .reset_index()
)

#looking at month over month growth/decline
monthly_sales['Unit_Growth'] = monthly_sales.groupby(['Brand', 'Package'])['Units_Sold'].pct_change().round(3)
monthly_sales['Dollar_Growth'] = monthly_sales.groupby(['Brand', 'Package'])['Dollars_Sold'].pct_change().round(3)

monthly_sales[(monthly_sales['Brand'] == 'Sierra Nevada Hazy IPA') & (monthly_sales['Package'] == '12pk Bottles')]
# Out:
#     year_month                   Brand       Package  Units_Sold  \
# 4      2024-01  Sierra Nevada Hazy IPA  12pk Bottles         597
# 13     2024-02  Sierra Nevada Hazy IPA  12pk Bottles         200
# 31     2024-04  Sierra Nevada Hazy IPA  12pk Bottles         296
# 45     2024-05  Sierra Nevada Hazy IPA  12pk Bottles         259
# 57     2024-06  Sierra Nevada Hazy IPA  12pk Bottles         277
# 70     2024-07  Sierra Nevada Hazy IPA  12pk Bottles         341
# 81     2024-08  Sierra Nevada Hazy IPA  12pk Bottles          38
# 91     2024-09  Sierra Nevada Hazy IPA  12pk Bottles         124
# 102    2024-10  Sierra Nevada Hazy IPA  12pk Bottles         333
# 120    2024-12  Sierra Nevada Hazy IPA  12pk Bottles         438
#
#      Dollars_Sold  Unit_Growth  Dollar_Growth
# 4         6010.46          NaN            NaN
# 13        9382.85       -0.665          0.561
# 31         978.03        0.480         -0.896
# 45        2047.41       -0.125          1.093
# 57        2354.42        0.069          0.150
# 70         309.39        0.231         -0.869
# 81        3675.08       -0.889         10.878
# 91        3275.52        2.263         -0.109
# 102       1749.63        1.685         -0.466
# 120       2739.23        0.315          0.566

# %%
monthly_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_month     127 non-null    object
#  1   Brand          127 non-null    object
#  2   Package        127 non-null    object
#  3   Units_Sold     127 non-null    int64
#  4   Dollars_Sold   127 non-null    float64
#  5   Unit_Growth    112 non-null    float64
#  6   Dollar_Growth  112 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
brand_growth = (monthly_sales
    .groupby(['year_month','Brand', 'Package'])
     .agg(
         avg_units_growth=('Unit_Growth', 'mean'),
         avg_dollars_growth=('Dollar_Growth', 'mean')
     )
     .reset_index()
)

brand_growth[(brand_growth['Package'] == '12pk Bottles') & (brand_growth['Brand'] == 'Sierra Nevada Torpedo')]
# Out:
#     year_month                  Brand       Package  avg_units_growth  \
# 37     2024-04  Sierra Nevada Torpedo  12pk Bottles               NaN
# 49     2024-05  Sierra Nevada Torpedo  12pk Bottles            -0.549
# 63     2024-06  Sierra Nevada Torpedo  12pk Bottles             0.141
# 74     2024-07  Sierra Nevada Torpedo  12pk Bottles            -0.156
# 85     2024-08  Sierra Nevada Torpedo  12pk Bottles            -0.358
# 97     2024-09  Sierra Nevada Torpedo  12pk Bottles             2.098
# 106    2024-10  Sierra Nevada Torpedo  12pk Bottles            -0.663
# 117    2024-11  Sierra Nevada Torpedo  12pk Bottles            -0.101
# 125    2024-12  Sierra Nevada Torpedo  12pk Bottles            -0.853
#
#      avg_dollars_growth
# 37                  NaN
# 49               -0.152
# 63                2.232
# 74               -0.711
# 85               -0.073
# 97                0.533
# 106               0.142
# 117               1.218
# 125              -0.330

# %%
avg_by_brand = (brand_growth
   .groupby(['Brand', 'Package'])
   .agg(
       mean_units_growth=('avg_units_growth', 'mean'),
       mean_dollars_growth=('avg_dollars_growth', 'mean')
   )
   .reset_index()
)

top_5 = avg_by_brand.sort_values('mean_units_growth', ascending=False).head(5)
bottom_5 = avg_by_brand.sort_values('mean_units_growth').head(5)

# %%
top_5
# Out:
#                      Brand       Package  mean_units_growth  \
# 3         Competitor Lager  12pk Bottles           4.785500
# 8   Sierra Nevada Hazy IPA  Single Draft           1.843444
# 0           Competitor IPA  12pk Bottles           1.562125
# 11  Sierra Nevada Pale Ale  Single Draft           1.549833
# 7   Sierra Nevada Hazy IPA      6pk Cans           1.454500
#
#     mean_dollars_growth
# 3              0.181333
# 8              1.321778
# 0              0.705250
# 11             0.448500
# 7              0.354667

# %%
bottom_5
# Out:
#                      Brand       Package  mean_units_growth  \
# 12   Sierra Nevada Torpedo  12pk Bottles          -0.055125
# 5         Competitor Lager  Single Draft           0.086286
# 14   Sierra Nevada Torpedo  Single Draft           0.267167
# 6   Sierra Nevada Hazy IPA  12pk Bottles           0.373778
# 10  Sierra Nevada Pale Ale      6pk Cans           0.375545
#
#     mean_dollars_growth
# 12             0.357375
# 5              0.870429
# 14             1.507000
# 6              1.212000
# 10             0.472091

# %%
corr = avg_by_brand['mean_units_growth'].corr(avg_by_brand['mean_dollars_growth'])

# %%
# making a dataframe for just the Torpedo 12pk bottles to see promotion vs unit/dollar correlation
torpedo = scan_data[(scan_data['Brand'] == 'Sierra Nevada Torpedo') & (scan_data['Package'] == '12pk Bottles')].copy()

# %%
# converting promo flag to an int
torpedo['Promoted_Flag'] = (torpedo['Promoted']=='Y').astype(int)

# %%
corr_units = torpedo['Promoted_Flag'].corr(torpedo['Units_Sold'])
corr_dollars = torpedo['Promoted_Flag'].corr(torpedo['Dollars_Sold'])

print(f"Corr with units sold: {corr_units:.2f}")
print(f"Corr with dollars sold: {corr_dollars:.2f}")
# Out:
# Corr with units sold: 0.19
# Corr with dollars sold: 0.24

# %%
# looking at promotional lifts
promo_summary = (scan_data
    .groupby(['Brand', 'Package', 'Promoted'])
     .agg(
         avg_units=('Units_Sold', 'mean'),
         avg_dollars=('Dollars_Sold', 'mean'),
         obs=('Units_Sold', 'size') # number of observations
     )
)

promo_summary
# Out:
#                                                avg_units  avg_dollars  obs
# Brand                  Package      Promoted
# Competitor IPA         12pk Bottles N         210.571429  2685.980000    7
#                                     Y         287.444444  3311.474444    9
#                        6pk Cans     N         259.500000  2910.061250    8
#                                     Y         222.250000  2201.997500    4
#                        Single Draft N         261.818182  1961.615455   11
#                                     Y         204.000000  2839.045000    2
# Competitor Lager       12pk Bottles N         149.625000  2273.140000    8
#                                     Y         156.166667  3000.960000    6
#                        6pk Cans     N         283.285714  2422.181429    7
#                                     Y         255.166667  2403.306667    6
#                        Single Draft N         305.583333  2811.202500   12
#                                     Y         280.333333  3375.353333    3
# Sierra Nevada Hazy IPA 12pk Bottles N         189.250000  2875.012500    8
#                                     Y         231.500000  1586.986667    6
#                        6pk Cans     N         306.222222  1937.400000    9
#                                     Y         275.500000  3976.420000    2
#                        Single Draft N         298.363636  2467.690000   11
#                                     Y          69.000000  2785.350000    2
# Sierra Nevada Pale Ale 12pk Bottles N         301.545455  2324.361818   11
#                                     Y         295.500000  2186.430000    2
#                        6pk Cans     N         369.400000  2119.552000   10
#                                     Y         315.600000  2793.840000    5
#                        Single Draft N         194.100000  3226.949000   10
#                                     Y         243.000000  1962.120000    6
# Sierra Nevada Torpedo  12pk Bottles N         268.400000  1591.611000   10
#                                     Y         321.333333  2431.386667    3
#                        6pk Cans     N         287.000000  2282.377500    8
#                                     Y         369.666667  2529.303333    3
#                        Single Draft N         220.750000  2658.045000    8
#                                     Y         298.000000  1561.856667    3

# %%
promo_pivot = (promo_summary
                    .pivot_table(index=['Brand', 'Package'],
                    columns='Promoted',
                    values=['avg_units', 'avg_dollars'])
)

promo_pivot.columns = ['avg_dollars_n', 'avg_dollars_y', 'avg_units_n', 'avg_units_y']

promo_pivot = promo_pivot.reset_index()

promo_pivot['dollars_lift_%'] = (promo_pivot['avg_dollars_y'] / promo_pivot['avg_dollars_n'] - 1) * 100

promo_pivot['unit_lift_%'] = (promo_pivot['avg_units_y'] / promo_pivot['avg_units_n'] - 1) * 100

promo_pivot.head()
# Out:
#               Brand       Package  avg_dollars_n  avg_dollars_y  avg_units_n  \
# 0    Competitor IPA  12pk Bottles    2685.980000    3311.474444   210.571429
# 1    Competitor IPA      6pk Cans    2910.061250    2201.997500   259.500000
# 2    Competitor IPA  Single Draft    1961.615455    2839.045000   261.818182
# 3  Competitor Lager  12pk Bottles    2273.140000    3000.960000   149.625000
# 4  Competitor Lager      6pk Cans    2422.181429    2403.306667   283.285714
#
#    avg_units_y  dollars_lift_%  unit_lift_%
# 0   287.444444       23.287383    36.506860
# 1   222.250000      -24.331575   -14.354528
# 2   204.000000       44.729947   -22.083333
# 3   156.166667       32.018265     4.372041
# 4   255.166667       -0.779246    -9.926038

# %%
top_5_unit_lift = promo_pivot.sort_values('unit_lift_%', ascending=False).head(5)
top_5_unit_lift
# Out:
#                      Brand       Package  avg_dollars_n  avg_dollars_y  \
# 0           Competitor IPA  12pk Bottles      2685.9800    3311.474444
# 14   Sierra Nevada Torpedo  Single Draft      2658.0450    1561.856667
# 13   Sierra Nevada Torpedo      6pk Cans      2282.3775    2529.303333
# 11  Sierra Nevada Pale Ale  Single Draft      3226.9490    1962.120000
# 6   Sierra Nevada Hazy IPA  12pk Bottles      2875.0125    1586.986667
#
#     avg_units_n  avg_units_y  dollars_lift_%  unit_lift_%
# 0    210.571429   287.444444       23.287383    36.506860
# 14   220.750000   298.000000      -41.240398    34.994337
# 13   287.000000   369.666667       10.818799    28.803717
# 11   194.100000   243.000000      -39.195816    25.193199
# 6    189.250000   231.500000      -44.800704    22.324967

# %%
bottom_5_unit_lift = promo_pivot.sort_values('unit_lift_%').head(5)
bottom_5_unit_lift
# Out:
#                      Brand       Package  avg_dollars_n  avg_dollars_y  \
# 8   Sierra Nevada Hazy IPA  Single Draft    2467.690000      2785.3500
# 2           Competitor IPA  Single Draft    1961.615455      2839.0450
# 10  Sierra Nevada Pale Ale      6pk Cans    2119.552000      2793.8400
# 1           Competitor IPA      6pk Cans    2910.061250      2201.9975
# 7   Sierra Nevada Hazy IPA      6pk Cans    1937.400000      3976.4200
#
#     avg_units_n  avg_units_y  dollars_lift_%  unit_lift_%
# 8    298.363636        69.00       12.872768   -76.873857
# 2    261.818182       204.00       44.729947   -22.083333
# 10   369.400000       315.60       31.812760   -14.564158
# 1    259.500000       222.25      -24.331575   -14.354528
# 7    306.222222       275.50      105.245174   -10.032656

# %%
# filtering to just the 6pk Hazy IPA to verify data - the pivot table dataframe shows a 105% increase in dollars 
# when it was promoted, but a -10% decline in units

# info is correct, but wonky with the random numbers I generated

scan_data[(scan_data['Brand'] == 'Sierra Nevada Hazy IPA') & (scan_data['Package'] == '6pk Cans')]
# Out:
#           Date      Account Market                   Brand   Package  \
# 97  2024-02-11       Kroger     PA  Sierra Nevada Hazy IPA  6pk Cans
# 98  2024-02-25       Kroger     CA  Sierra Nevada Hazy IPA  6pk Cans
# 99  2024-04-14       Publix     CA  Sierra Nevada Hazy IPA  6pk Cans
# 100 2024-04-14       Costco     CA  Sierra Nevada Hazy IPA  6pk Cans
# 101 2024-06-23      Safeway     PA  Sierra Nevada Hazy IPA  6pk Cans
# 102 2024-07-07  Whole Foods     TX  Sierra Nevada Hazy IPA  6pk Cans
# 103 2024-09-01       Publix     CA  Sierra Nevada Hazy IPA  6pk Cans
# 104 2024-09-15  Whole Foods     CA  Sierra Nevada Hazy IPA  6pk Cans
# 105 2024-11-10       Kroger     PA  Sierra Nevada Hazy IPA  6pk Cans
# 106 2024-11-17  Whole Foods     CO  Sierra Nevada Hazy IPA  6pk Cans
# 107 2024-12-08       Publix     CO  Sierra Nevada Hazy IPA  6pk Cans
#
#      Units_Sold  Dollars_Sold Promoted year_month
# 97          126       4808.64        Y    2024-02
# 98          333       4871.76        N    2024-02
# 99          369        297.24        N    2024-04
# 100         366       4428.27        N    2024-04
# 101         320        486.04        N    2024-06
# 102          73       1335.88        N    2024-07
# 103         430       1785.62        N    2024-09
# 104         372       1952.86        N    2024-09
# 105         183        723.45        N    2024-11
# 106         310       1555.48        N    2024-11
# 107         425       3144.20        Y    2024-12

# %% [markdown]
# ## 💡 Key Insights — Product Growth & Promotion Impact
#
# **Overall Findings**
# - *Torpedo 12 pk Bottles* shows the strongest promotional response (**+53 % dollar lift**, **≈ +20 % unit lift**), indicating effective promotions and strong consumer pull.
# - *Hazy IPA 12 pk Bottles* shows **+22 % unit lift** but **−45 % dollar lift**, suggesting deeper discounting or lower-priced accounts during promotions.
# - *Pale Ale 6 pk Cans* shows **+32 % dollar lift** but **−15 % unit lift**, implying pricing-driven gains without volume growth.
# - *Hazy IPA 6 pk Cans* shows **+105 % dollar lift** with **−10 % unit lift**, likely reflecting mix or premium placement effects.
#
#
# * **Month-over-Month Performance**
# * **Torpedo 12 pk Bottles** shows the strongest promotional response, with **+53 % dollar lift** and **+20 % unit lift**, indicating effective promotions and healthy consumer demand.
# * **Hazy IPA 12 pk Bottles** increased **units (+22 %)** but saw a **–45 % dollar lift**, suggesting deeper discounting or promotions concentrated in lower-priced markets.
#
#
# **Correlation Insight**
# - The overall correlation between unit and dollar growth (**r = 0.42**) indicates a **modest positive relationship**.
#   Pricing, product mix, and promotion strategy are key factors influencing value growth beyond pure sales volume.
#
# ---

# %% [markdown]
# ## **2. How does SNBC’s sales growth compare to the category average in each market?**

# %%
# aggregating SNBC vs competitor sales by market and month

agg_monthly_sales = scan_data.groupby(['year_month', 'Market', 'Brand'])[['Units_Sold', 'Dollars_Sold']].sum()

agg_monthly_sales
# Out:
#                                           Units_Sold  Dollars_Sold
# year_month Market Brand
# 2024-01    CA     Competitor IPA                 164        605.01
#                   Competitor Lager               498       1073.51
#                   Sierra Nevada Pale Ale         300       2496.89
#                   Sierra Nevada Torpedo           74       3152.94
#            CO     Competitor Lager               164       3162.94
# ...                                              ...           ...
# 2024-12    PA     Sierra Nevada Pale Ale         430       4707.19
#                   Sierra Nevada Torpedo          186        962.21
#            TX     Competitor IPA                 350       3579.57
#                   Sierra Nevada Hazy IPA         334        704.18
#                   Sierra Nevada Torpedo          393        517.69
#
# [147 rows x 2 columns]

# %%
agg_monthly_units_pivot = (agg_monthly_sales
                             .pivot_table(index=['year_month', 'Market'],
                                         columns='Brand',
                                         values='Units_Sold',
                                         aggfunc='sum',
                                         fill_value=0)
                             .reset_index()
                            )

agg_monthly_units_pivot.head(10)
# Out:
# Brand year_month Market  Competitor IPA  Competitor Lager  \
# 0        2024-01     CA             164               498
# 1        2024-01     CO               0               164
# 2        2024-01     NC               0                 0
# 3        2024-01     PA               0               488
# 4        2024-01     TX               0               215
# 5        2024-02     CA             297                 0
# 6        2024-02     CO               0                 0
# 7        2024-02     NC               0                 0
# 8        2024-02     PA             178                 0
# 9        2024-02     TX               0               211
#
# Brand  Sierra Nevada Hazy IPA  Sierra Nevada Pale Ale  Sierra Nevada Torpedo
# 0                           0                     300                     74
# 1                         182                       0                    266
# 2                         260                     405                      0
# 3                         337                       0                      0
# 4                           0                       0                      0
# 5                         333                       0                      0
# 6                          75                     391                    499
# 7                         200                       0                    174
# 8                         126                       0                      0
# 9                           0                       0                      0

# %%
agg_monthly_units_pivot['SNBC_Total'] = (agg_monthly_units_pivot['Sierra Nevada Hazy IPA'] +
                                            agg_monthly_units_pivot['Sierra Nevada Pale Ale'] +
                                            agg_monthly_units_pivot['Sierra Nevada Torpedo']   
)

agg_monthly_units_pivot['Category_Total'] = (agg_monthly_units_pivot['Competitor IPA'] +
                                            agg_monthly_units_pivot['Competitor Lager'] +
                                            agg_monthly_units_pivot['SNBC_Total']   
)

agg_monthly_units_pivot.head(20)
# Out:
# Brand year_month Market  Competitor IPA  Competitor Lager  \
# 0        2024-01     CA             164               498
# 1        2024-01     CO               0               164
# 2        2024-01     NC               0                 0
# 3        2024-01     PA               0               488
# 4        2024-01     TX               0               215
# 5        2024-02     CA             297                 0
# 6        2024-02     CO               0                 0
# 7        2024-02     NC               0                 0
# 8        2024-02     PA             178                 0
# 9        2024-02     TX               0               211
# 10       2024-03     CA               0                57
# 11       2024-03     CO             498               300
# 12       2024-03     NC               0                 0
# 13       2024-03     PA               0                 0
# 14       2024-03     TX               0               456
# 15       2024-04     CA             292               426
# 16       2024-04     CO             627               410
# 17       2024-04     NC             157                 0
# 18       2024-04     PA               0               626
# 19       2024-04     TX               0               275
#
# Brand  Sierra Nevada Hazy IPA  Sierra Nevada Pale Ale  Sierra Nevada Torpedo  \
# 0                           0                     300                     74
# 1                         182                       0                    266
# 2                         260                     405                      0
# 3                         337                       0                      0
# 4                           0                       0                      0
# 5                         333                       0                      0
# 6                          75                     391                    499
# 7                         200                       0                    174
# 8                         126                       0                      0
# 9                           0                       0                      0
# 10                          0                       0                      0
# 11                          0                     420                      0
# 12                        400                       0                      0
# 13                          0                     412                    418
# 14                        428                       0                      0
# 15                       1120                       0                    396
# 16                          0                     244                      0
# 17                          0                     461                     27
# 18                          0                       0                      0
# 19                        296                     972                    487
#
# Brand  SNBC_Total  Category_Total
# 0             374            1036
# 1             448             612
# 2             665             665
# 3             337             825
# 4               0             215
# 5             333             630
# 6             965             965
# 7             374             374
# 8             126             304
# 9               0             211
# 10              0              57
# 11            420            1218
# 12            400             400
# 13            830             830
# 14            428             884
# 15           1516            2234
# 16            244            1281
# 17            488             645
# 18              0             626
# 19           1755            2030

# %%
# making year_month a datetime for plotting, making sure all values are sorted properly for plotting

agg_monthly_units_pivot['year_month'] = pd.to_datetime(agg_monthly_units_pivot['year_month'])
agg_monthly_units_pivot = agg_monthly_units_pivot.sort_values(['Market', 'year_month'])

# %%
agg_monthly_units_pivot['SNBC_Share'] = (agg_monthly_units_pivot['SNBC_Total'] /
                                            agg_monthly_units_pivot['Category_Total'])

agg_monthly_units_pivot.head()
# Out:
# Brand year_month Market  Competitor IPA  Competitor Lager  \
# 0     2024-01-01     CA             164               498
# 5     2024-02-01     CA             297                 0
# 10    2024-03-01     CA               0                57
# 15    2024-04-01     CA             292               426
# 20    2024-05-01     CA             327               480
#
# Brand  Sierra Nevada Hazy IPA  Sierra Nevada Pale Ale  Sierra Nevada Torpedo  \
# 0                           0                     300                     74
# 5                         333                       0                      0
# 10                          0                       0                      0
# 15                       1120                       0                    396
# 20                          0                       0                    333
#
# Brand  SNBC_Total  Category_Total  SNBC_Share
# 0             374            1036    0.361004
# 5             333             630    0.528571
# 10              0              57    0.000000
# 15           1516            2234    0.678603
# 20            333            1140    0.292105

# %%
# plotting category share by Market

for market, subset in agg_monthly_units_pivot.groupby('Market'):
    plt.figure(figsize=(10,6))
    plt.plot(subset['year_month'], subset['SNBC_Share'], marker='o', label='Sierra Nevada Category Share')
    
    plt.title(f"{market} - Sierra Nevada Brewing Share")
    plt.xlabel('Month')
    plt.ylabel('Share of Category')
    plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    plt.xticks(rotation=45)
    plt.ylim(-0.1,1.1)
    plt.show()

# %% [markdown]
# ## 📊 Market-Level Summary — Sierra Nevada Category Share
#
# ### **California (CA)**
# - Share ranged widely from **0% → 100%**, with volatile periods due to months of no sales followed by strong re-entries.
# - Peak share in **Aug (100%)** and **Sep (81%)**, showing SNBC dominance when active.
# - Lowest share in **Mar and Dec (0%)** where no Sierra Nevada sales were recorded.
# - Trend: **Inconsistent presence**, but when distributed, SNBC commands majority of category volume.
#
# ---
#
# ### **Colorado (CO)**
# - SNBC maintained **strong share** overall, often above **60%**, peaking at **100%** in Feb and Nov.
# - Lowest share in **Apr (19%)** when competitor activity spiked.
# - Ended the year at **63%**, showing **steady performance** despite fluctuations mid-year.
# - Trend: **Sierra Nevada leads most months**, with minor dips tied to competitor reactivations.
#
# ---
#
# ### **North Carolina (NC)**
# - Early-year dominance (**100% share Jan–Mar**) before dipping mid-year as competitors entered.
# - Lowest share in **Sep (45%)**, then rebounded to **100% by Oct and Dec**.
# - Trend: **Strong regional control** with brief mid-year competition pressure, ending on top.
#
# ---
#
# ### **Pennsylvania (PA)**
# - Share started moderate (**41%–42% in Q1**), dipped to **0% Apr–May**, then recovered in June (**76%**) and stabilized near **60%** late in the year.
# - Lowest share: **0% in Apr–May**, no SNBC sales.
# - Trend: **Recovery story** — after early outages, SNBC regained share through consistent late-year performance.
#
# ---
#
# ### **Texas (TX)**
# - Began with **0% share** in Jan–Feb, then surged to **86% in Apr** driven by strong Hazy IPA and Pale Ale performance.
# - Dipped mid-year but recovered to **~68% by Dec**.
# - Trend: **Fast-growing presence** — SNBC entered late but gained traction quickly and sustained strong market share.
#
# ---
#
# ### **Overall Takeaways**
# - **Sierra Nevada leads or dominates in most active markets**, particularly **CO, NC, and TX**.
# - **Volatility** in CA and PA stems from intermittent months with no recorded sales.
# - When present, **SNBC typically holds >60% share**, reflecting brand strength where distributed.
# - Markets with early-year gaps may benefit from **consistent distribution and promotional continuity** to stabilize share performance.

# %%
# Average share by market

(agg_monthly_units_pivot
 .groupby(['Market'], as_index=False)['Category_Share'].mean()
 .sort_values('Category_Share', ascending=False)
)
# Out:
# Brand Market  Category_Share
# 2         NC        0.777310
# 1         CO        0.597724
# 4         TX        0.544338
# 3         PA        0.463202
# 0         CA        0.447792

# %% [markdown]
# ## 🧭 Average Category Share by Market
#
# | Market | Avg. Category Share | Interpretation |
# |:-------|:-------------------:|:---------------|
# | **NC** | **77.7%** | Sierra Nevada holds the dominant position, maintaining strong category leadership throughout the year. |
# | **CO** | **59.8%** | Consistent share and stable performance — Sierra Nevada is a clear leader but faces steady competition. |
# | **TX** | **54.4%** | Rapid share growth following mid-year expansion, suggesting momentum in a developing market. |
# | **PA** | **46.3%** | Competitive landscape with share recovery in later months; opportunity for sustained presence. |
# | **CA** | **44.8%** | Volatile performance due to inconsistent availability; strong peaks offset by months with minimal sales. |
#
# **Overall Insight:**
# Sierra Nevada leads the category in **most markets**, averaging **56% share** overall. The brand is particularly strong in **NC and CO**, while **CA and PA** show growth potential if distribution gaps and volatility are addressed.
